# %% [markdown]
# <a href="https://colab.research.google.com/github/adrian-alejandro/autoML/blob/main/AutoML_Practico_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.0.4-py3-none-any.whl (348 kB)
#      |████████████████████████████████| 348 kB 5.2 MB/s
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (1.4.44)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 48.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (21.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from optuna) (4.64.1)
# Collecting cliff
#   Downloading cliff-4.1.0-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 10.4 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from optuna) (6.0)
# Requirement already satisfied: scipy<1.9.0,>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (1.7.3)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata<5.0.0 in /usr/local/lib/python3.8/dist-packages (from optuna) (4.13.0)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic>=1.5.0->optuna) (5.10.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.0 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata<5.0.0->optuna) (3.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-4.1.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.5 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from cliff->optuna) (3.5.0)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 64.2 MB/s
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.8/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.8/dist-packages (from cmd2>=1.0.0->cliff->optuna) (22.1.0)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 56.0 MB/s
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.8/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=693144866aa0d0dc10c8917330f6209c6003f6d33e222395813ded24ea4897fa
#   Stored in directory: /root/.cache/pip/wheels/7f/1a/65/84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.8.1 autopage-0.5.1 cliff-4.1.0 cmaes-0.9.0 cmd2-2.4.2 colorlog-6.7.0 optuna-3.0.4 pbr-5.11.0 pyperclip-1.8.2 stevedore-4.1.1

# %%
import os
from io import BytesIO
import requests
import pandas as pd
import numpy as np
import optuna

from sklearn import datasets
from sklearn import model_selection
from sklearn import svm, naive_bayes, linear_model
from sklearn.metrics import balanced_accuracy_score, make_scorer

# %%
vectorized_dataset_url = "https://raw.githubusercontent.com/adrian-alejandro/Busqueda-y-Recomendacion-para-Textos-Legales-Mentoria-2022/main/embeddings/vectorized_dataset_X_y.npz"
processed_data_url = "https://raw.githubusercontent.com/adrian-alejandro/Busqueda-y-Recomendacion-para-Textos-Legales-Mentoria-2022/main/embeddings/processed_dataset.csv"

# %%
vector_file = os.path.split(vectorized_dataset_url)[1]
dataset = os.path.split(processed_data_url)[1]

# %%
def read_npz_from_url(url):
  """Function that reads a npz file from a URL and overrides np.load method to
   force allow_pickle.
   Ref: https://stackoverflow.com/questions/55890813/how-to-fix-object-arrays-cannot-be-loaded-when-allow-pickle-false-for-imdb-loa
  """
  # save np.load
  np_load_old = np.load

  # modify the default parameters of np.load
  np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

  r = requests.get(url, stream=True)

  # call load_data with allow_pickle implicitly set to true
  vectors = np.load(BytesIO(r.raw.read()))

  # restore np.load for future normal usage
  np.load = np_load_old

  return vectors

# %%
vectors = read_npz_from_url(vectorized_dataset_url)

# Texto vectorizado
X = vectors['X']
                                            

# Etiquetas (fueros)
y = vectors['y']

# %%
data = pd.read_csv(processed_data_url, sep='|', encoding='utf-8')
data.head()
# Out:
#                                              archivo    fuero  \
# 0                          9 BAEZ-FLECHA BUS.pdf.txt  LABORAL
# 1                            90 FUNES-COYSPU.pdf.txt  LABORAL
# 2                     1 QUINTEROS-CONSOLIDAR.pdf.txt  LABORAL
# 3  3 SANGUEDOLCE-MUNICIPALIDAD DE VILLA ALLENDE.p...  LABORAL
# 4                        188 LUCIANO-NICOLAS.pdf.txt  LABORAL
#
#                                          texto_clean
# 0  ['sala', 'laboral', 'tribunal', 'superior', 'p...
# 1  ['sala', 'laboral', 'tribunal', 'superior', 'p...
# 2  ['sala', 'laboral', 'tribunal', 'superior', 'p...
# 3  ['sala', 'laboral', 'tribunal', 'superior', 'p...
# 4  ['sala', 'laboral', 'tribunal', 'superior', 'p...

# %%
#Step 1. Define an objective function to be maximized.
def objective(trial):

    classifier_name = trial.suggest_categorical("classifier", ["LogReg", "SVM", "MNB"])
    
    # Step 2. Setup values for the hyperparameters:
    if classifier_name == 'LogReg':
      # Seach space
      logreg_c = trial.suggest_float("logreg_c", 1e-10, 1e10, log=True)
      logreg_solver = trial.suggest_categorical("logreg_solver", ['newton-cg', 'lbfgs', 'sag', 'saga'])
      logreg_fit_intercept = trial.suggest_categorical("logreg_intercept", [False, True])
      logreg_penalty = trial.suggest_categorical("logreg_penalty", ['l1', 'l2', 'elasticnet', 'none'])
      # Estimator
      classifier_obj = linear_model.LogisticRegression(
          C=logreg_c,
          solver=logreg_solver,
          fit_intercept=logreg_fit_intercept,
          penalty=logreg_penalty)
    elif classifier_name == "SVM":
      # Search space
      svm_c = trial.suggest_float("svm_c", 1e-1, 1e1)
      svm_kernel = trial.suggest_categorical("svm_kernel", ['poly', 'linear', 'rbf', 'sigmoid'])
      svm_gamma = trial.suggest_categorical("svm_gamma", ['scale', 'auto'])
      svm_shrinking = trial.suggest_categorical("svm_shrinking", [True, False])
      svm_break_ties = trial.suggest_categorical("svm_break_ties", [True, False])
      svm_decision_function_shape = trial.suggest_categorical("svm_decision_function_shape", ['ovo', 'ovr'])
      # Estimator
      classifier_obj = svm.SVC(
            C=svm_c, 
            kernel=svm_kernel,
            gamma=svm_gamma,
            shrinking=svm_shrinking,
            break_ties=svm_break_ties,
            decision_function_shape=svm_decision_function_shape)
    else:
      # Search space
      mnb_alpha = trial.suggest_float("mnb_alpha", 1e-1, 1e1)
      mnb_fit_prior = trial.suggest_categorical("mnb_fit_prior", [True, False])
      # Estimator
      classifier_obj = naive_bayes.MultinomialNB(
          alpha=mnb_alpha,
          fit_prior=mnb_fit_prior)

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(
        classifier_obj, 
        X,
        y,
        n_jobs=-1,
        cv=5,
        scoring=make_scorer(balanced_accuracy_score))
    balanced_accuracy = score.mean()
    return balanced_accuracy

study = optuna.create_study(direction="maximize")

study.optimize(objective, n_trials=50)


best_trial = study.best_trial

print(best_trial.params )
print(best_trial.value)
# Out:
# [I 2022-12-10 22:26:36,728] A new study created in memory with name: no-name-d05652a5-3d6b-4bc0-97ec-1c428e0e4039
# [I 2022-12-10 22:26:42,105] Trial 0 finished with value: 0.9630000000000001 and parameters: {'classifier': 'LogReg', 'logreg_c': 19.181756661149585, 'logreg_solver': 'newton-cg', 'logreg_intercept': False, 'logreg_penalty': 'none'}. Best is trial 0 with value: 0.9630000000000001.
# [I 2022-12-10 22:27:18,302] Trial 1 finished with value: 0.9713333333333335 and parameters: {'classifier': 'LogReg', 'logreg_c': 4250632642.9724655, 'logreg_solver': 'sag', 'logreg_intercept': False, 'logreg_penalty': 'l2'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:18,583] Trial 2 finished with value: 0.7134253246753247 and parameters: {'classifier': 'MNB', 'mnb_alpha': 4.9026558464835555, 'mnb_fit_prior': False}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:21,164] Trial 3 finished with value: 0.25 and parameters: {'classifier': 'SVM', 'svm_c': 2.1005276009028306, 'svm_kernel': 'poly', 'svm_gamma': 'auto', 'svm_shrinking': False, 'svm_break_ties': False, 'svm_decision_function_shape': 'ovr'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:23,721] Trial 4 finished with value: 0.25 and parameters: {'classifier': 'SVM', 'svm_c': 0.2858362964208204, 'svm_kernel': 'poly', 'svm_gamma': 'auto', 'svm_shrinking': False, 'svm_break_ties': False, 'svm_decision_function_shape': 'ovo'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:23,898] Trial 5 finished with value: 0.25 and parameters: {'classifier': 'MNB', 'mnb_alpha': 9.369789667947598, 'mnb_fit_prior': True}. Best is trial 1 with value: 0.9713333333333335.
# [W 2022-12-10 22:27:26,170] Trial 6 failed because of the following error: The value nan is not acceptable.
# [I 2022-12-10 22:27:26,445] Trial 7 finished with value: 0.7134253246753247 and parameters: {'classifier': 'MNB', 'mnb_alpha': 3.70679534616171, 'mnb_fit_prior': False}. Best is trial 1 with value: 0.9713333333333335.
# [W 2022-12-10 22:27:28,231] Trial 8 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:27:28,423] Trial 9 failed because of the following error: The value nan is not acceptable.
# [I 2022-12-10 22:27:28,706] Trial 10 finished with value: 0.25 and parameters: {'classifier': 'MNB', 'mnb_alpha': 8.804071202783396, 'mnb_fit_prior': True}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:31,130] Trial 11 finished with value: 0.9546666666666667 and parameters: {'classifier': 'SVM', 'svm_c': 5.436197896059324, 'svm_kernel': 'linear', 'svm_gamma': 'scale', 'svm_shrinking': False, 'svm_break_ties': True, 'svm_decision_function_shape': 'ovr'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:27:31,410] Trial 12 finished with value: 0.7320616883116884 and parameters: {'classifier': 'MNB', 'mnb_alpha': 0.4581494836545619, 'mnb_fit_prior': False}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:28:06,286] Trial 13 finished with value: 0.961 and parameters: {'classifier': 'LogReg', 'logreg_c': 1468090427.2301188, 'logreg_solver': 'sag', 'logreg_intercept': False, 'logreg_penalty': 'l2'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:28:09,894] Trial 14 finished with value: 0.9630000000000001 and parameters: {'classifier': 'LogReg', 'logreg_c': 0.0019568483427725276, 'logreg_solver': 'newton-cg', 'logreg_intercept': False, 'logreg_penalty': 'none'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:28:13,514] Trial 15 finished with value: 0.9630000000000001 and parameters: {'classifier': 'LogReg', 'logreg_c': 574116075.8952678, 'logreg_solver': 'newton-cg', 'logreg_intercept': False, 'logreg_penalty': 'none'}. Best is trial 1 with value: 0.9713333333333335.
# [I 2022-12-10 22:28:16,676] Trial 16 finished with value: 0.25 and parameters: {'classifier': 'LogReg', 'logreg_c': 2.1253677241545562e-10, 'logreg_solver': 'sag', 'logreg_intercept': True, 'logreg_penalty': 'l2'}. Best is trial 1 with value: 0.9713333333333335.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:16,875] Trial 17 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,075] Trial 18 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,174] Trial 19 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,377] Trial 20 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,580] Trial 21 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,792] Trial 22 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:17,994] Trial 23 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:18,199] Trial 24 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:18,399] Trial 25 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:18,497] Trial 26 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:18,697] Trial 27 failed because of the following error: The value nan is not acceptable.
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-12-10 22:28:18,896] Trial 28 failed because of the following error: The value nan is not acceptable.
# [I 2022-12-10 22:29:20,632] Trial 29 finished with value: 0.9693333333333334 and parameters: {'classifier': 'LogReg', 'logreg_c': 78.99250369287363, 'logreg_solver': 'saga', 'logreg_intercept': False, 'logreg_penalty': 'l1'}. Best is trial 1 with value: 0.9713333333333335.

# %%
from optuna.visualization import plot_optimization_history

plot_optimization_history(study).show()
